# %%
import pandas as pd

# %%
n = pd.read_excel("C:\\Users\\tengliming\\Desktop\\python\\python数据分析入门\\代码\\3.1\\练习1数据.xlsx")
n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 7 columns):
# Unnamed: 0    16 non-null object
# Unnamed: 1    16 non-null object
# Unnamed: 2    16 non-null object
# Unnamed: 3    16 non-null object
# Unnamed: 4    16 non-null object
# Unnamed: 5    16 non-null object
# Unnamed: 6    16 non-null object
# dtypes: object(7)
# memory usage: 976.0+ bytes

# %%
 n["GAP"] = round(sum([n.课程1成绩 * n.课程1学分，n.课程2成绩 * n.课程2学分，n.课程3成绩 * n.课程3学分]) / sum ([n.课程1学分,n.课程2学分,n.课程3学分]),2)
# Out:
#   File "<ipython-input-7-302948727ad3>", line 1
#     n["GAP"] = round(sum([n.课程1成绩 * n.课程1学分，n.课程2成绩 * n.课程2学分，n.课程3成绩 * n.课程3学分]) / sum ([n.课程1学分,n.课程2学分,n.课程3学分]),2)
#                                             ^
# SyntaxError: invalid character in identifier

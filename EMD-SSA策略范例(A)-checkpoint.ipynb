# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import talib 
pd.options.mode.chained_assignment = None

# Dickey-Fuller test
from statsmodels.tsa.stattools import adfuller
#from scipy.signal import hilbert  区别 from statsmodels.tsa.stattools import
from pyhht.utils import inst_freq
from pyhht import EMD

import tushare as ts
pro = ts.pro_api('9293b9b01414a95f89aa75f884c907fdc2cd24f41c8ea3de863eaa26')

# %%
#复权个股日线
sd = '20191215'
ed = '20210806'

#tc = '399300.SZ'
tc = '600438.SH'
#tc = '002493.SZ'
#tc = '600036.SH'

#['600438.SS','601168.SS','600765.SS']
#'601012.SS', '600438.SS','300014.SZ','002460.SZ','600745.SS','603986.SS','603005.SS'
#,'603501.SS','601168.SS','600309.SS','002493.SZ','600176.SS','600426.SS','600989.SS','600893.SS'
#,'600760.SS','000733.SZ','600765.SS','002373.SZ','600033.SS','600036.SS'
data = ts.pro_bar(api=pro, ts_code=tc, adj='qfq', start_date=sd, end_date=ed,freq='d')  ##个股日线freq='d' 周线freq='w'

#data = pro.index_daily(ts_code=tc, adj='qfq', start_date=sd, end_date=ed)     ##指数日线
#data = pro.index_weekly(ts_code=tc, adj='qfq', start_date='20190101', end_date='20210526')    ##指数周线

data = data[::-1].reset_index(drop=True) #初始索引倒置
data['trade_date'] = pd.to_datetime(data['trade_date'],format='%Y%m%d')
data.set_index('trade_date', inplace=True)

#df = data[-144:]

# %%
df = data.tail(144)

#df['f_close'] = forcast(df['close'],21)
#df['f_close'] = df['close'].ewm(span=3).mean()
df['w_close']=df['close'].rolling(5).mean()

plt.figure(figsize=(15, 5))
#plt.figure(figsize=(10,6), dpi=256)
plt.title(str(tc))

plt.plot(data['close'], color="Green", linewidth=0.3, linestyle="-")
plt.plot(df['close'], color="red", linewidth=0.3, linestyle="-")
plt.plot(df['w_close'], color = "blue",  linewidth=0.3, linestyle="-")

# %%
def ssa(series, windowLen , pcn  ):
    seriesLen = len(series)
    K = seriesLen - windowLen + 1
    X = np.zeros((windowLen, K))
    for i in range(K):
        X[:, i] = series[i:i + windowLen]
    
    U, sigma, VT = np.linalg.svd(X, full_matrices=False)

    for i in range(VT.shape[0]):
        VT[i, :] *= sigma[i]
    A = VT

    rec = np.zeros((windowLen, seriesLen))
    for i in range(windowLen):
        for j in range(windowLen-1):
            for m in range(j+1):
                rec[i, j] += A[i, j-m] * U[m, i]
            rec[i, j] /= (j+1)
        for j in range(windowLen-1, seriesLen - windowLen + 1):
            for m in range(windowLen):
                rec[i, j] += A[i, j-m] * U[m, i]
            rec[i, j] /= windowLen
        for j in range(seriesLen - windowLen + 1, seriesLen):
            for m in range(j-seriesLen+windowLen, windowLen):
                rec[i, j] += A[i, j - m] * U[m, i]
            rec[i, j] /= (seriesLen - j)
    
    result = np.sum(rec[:pcn], axis=0)
    return result[-1]
    #return result

# %%
 #------------------------------EMA多头判断------------------------------------------------------------------
df['ema5']  = df['close'].ewm(span=3).mean()
df['ema10']  = df['close'].ewm(span=10).mean()
df['ema20']  = df['close'].ewm(span=30).mean()
df['ema60']  = df['close'].ewm(span=60).mean()

#---------------------------------------------------------------------------------------
plt.figure(figsize=(15, 5))
plt.title(str(tc))

plt.plot(df['close'], color="green", linewidth=0.3, linestyle="-")
plt.plot(df['ema5'], color="red", linewidth=0.3, linestyle="-")
plt.plot(df['ema20'], color = "blue",  linewidth=0.3, linestyle="-")

# %%
#--------------------------------------------------------------------------------------------------------  
pcn = 1
fwl = 2
swl = 5
dwl = 3
#---------------------------------三SSA-------------------------------------------------
df['f_ssa'] = df['close'].rolling(2*fwl).apply(ssa,args = (fwl,pcn),raw = True) 
df['s_ssa'] = df['close'].rolling(2*swl).apply(ssa,args = (swl,pcn),raw = True) 
df['w_ssa'] = df['w_close'].rolling(2*dwl).apply(ssa,args = (dwl,pcn),raw = True) 
#---------------------------------------------------------------------------------------
plt.figure(figsize=(15, 5))
plt.title(str(tc))

plt.plot(df['close'], color="black", linewidth=0.3, linestyle="-")
plt.plot(df['f_ssa'], color="green", linewidth=0.3, linestyle="-")
plt.plot(df['s_ssa'], color="red", linewidth=0.3, linestyle="-")
plt.plot(df['w_ssa'], color = "blue",  linewidth=0.3, linestyle="-")

# %%
#---------------------------------买卖点策略-------------------------------------------------
#DataFrame.diff(periods=1, axis=0) ; periods：移动的幅度，int类型，默认值为1;
# axis：移动的方向，{0 or ‘index’, 1 or ‘columns’}，
# 如果为0或者’index’，则上下移动，如果为1或者’columns’，则左右移动。
df['dfe'] = df['f_ssa']-df['ema5']
df['dtf'] = df['f_ssa']-df['f_ssa'].shift(1) 
df['dts'] = df['s_ssa']-df['s_ssa'].shift(1) 
df['dtw'] = df['w_ssa']-df['w_ssa'].shift(1) 

#df['ddx'] =  (df['dtf']>0.0000)  & (df['dts']>0) & (df['dtw']>0.0000)  
df['ddx'] =  (df['dtf']>0.0000)  & (df['dtw']>0) & (df['dfe']>0.0000) 
#print(df['ddx'])

#---------------------------------回测收益-------------------------------------------------
df['res'] = np.select([df['ddx'] > 0],[df['close']],default = np.nan)  #获取快慢SSA >0的时序
df['attack'] = np.select([df['ddx'] > 0],[1],default = 0)#获取“双SSA斜率差 >0策略”的时序的触发信号

bs = np.array(df['attack'])

#print("买卖信号A:"+str(bs[-1]))

df['buy'] = df['attack'].shift(1) #下移一行买入信号
bs2 = np.array(df['buy'])
#print("买卖信号B:"+str(bs2[-1]))
#print(np.array(df['buy']))

df['base_profit'] = 1+0.01*df['pct_chg'].fillna(0) #计算基准每日收益
df['prod_base_profit'] = df['base_profit'].cumprod()-1 #计算基准每日收益累乘
df['profit'] = np.select([df['buy'] == 1],[df['base_profit']],default = 1) #计算策略每日收益
df['profit'] = df['profit'].fillna(0)
#print(np.array(data['profit']))

df['prod_profit'] = df['profit'].cumprod()-1#计算策略每日收益累乘
df['max_profit'] = df['prod_profit'].max()

plt.figure(figsize=(15, 5))
plt.title(str(tc))

plt.plot(df['prod_profit'], color="red", linewidth=0.3, linestyle="-")
plt.plot(df['prod_base_profit'], color = "blue",  linewidth=0.3, linestyle="-")

print("策略收益率："+str(np.array(df['prod_profit'])[-1])) 
print("基准收益率："+str(np.array(df['prod_base_profit'])[-1]))
# Out:
# 策略收益率：0.40366878608444656
# 基准收益率：0.22445162101391714

# %%
plt.figure(figsize=(15,6))
#plt.figure(figsize=(15,6), dpi=256)
plt.title(str(tc))
#plt.axhline(0, linewidth=0.6, linestyle='--', color='red') 
#plt.axvline(0, linestyle='--', color='red'

#plt.plot(returns, color="blue",  linewidth=0.2, linestyle="-")

plt.plot(df['close'], color="green", linewidth=0.6, linestyle="-")
plt.plot(df['res'], color = "red",  linewidth=1, linestyle="-")
#plt.plot(data['s_ssa'], color="blue",  linewidth=0.2, linestyle="-")

# %%
# convert strings to dates
ftseinfo = df
ftseinfo['Date'] = ftseinfo.index
#print(ftseinfo['trade_date'])
ftseinfo['Date'] = pd.to_datetime(ftseinfo['Date'], format="%d-%b-%Y" )

# convenience variable for plots
date_axis = ftseinfo['Date']

# The date entries are not evenly spaced, so calculate number of days from first date for each
first_date = date_axis[0]
deltas = ftseinfo['Date'] - first_date

def getdays(delta):
    return delta.days

ftseinfo['deltadays'] = deltas.apply(getdays)

# convenience variable for days
days = ftseinfo['deltadays']
# plot closing price
fig = plt.figure(figsize=(12,6))
sp1 = fig.add_subplot(111)
plt.xlabel('date')
plt.ylabel('price')

sp1.plot_date( x=date_axis, y=ftseinfo['close'] , linewidth=1, linestyle= 'dotted', color='blue') #values are '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

plt.legend(loc=0, fontsize='xx-small')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
def adf_test(timeseries):
    dftest = adfuller(timeseries, autolag='AIC')
    print('ADF Statistic: %f' % dftest[0])
    print('p-value: %f' % dftest[1])
    print('p-value阀值:0.05，p-value大于0.05，认为这组时间序列是非平稳的，需要改进。')
    print('Critical Values:')
    for key, value in dftest[4].items():
        print('\t%s: %.3f' % (key, value))
print('原始数据稳态分析：')
adf_test( ftseinfo['close'] )
# Out:
# 原始数据稳态分析：
# ADF Statistic: -1.511401
# p-value: 0.527864
# p-value阀值:0.05，p-value大于0.05，认为这组时间序列是非平稳的，需要改进。
# Critical Values:
# 	1%: -3.477
# 	5%: -2.882
# 	10%: -2.578

# %%
def decompose( x, y ):
    decomposer = EMD( y )
    imfs = decomposer.decompose()
    return imfs
def emd_analysis( days, data_values ):

    # decompose time series into intrinsic mode functions
    imfs = decompose(days, data_values)

    # extract the residue (overall trend)
    imf_residue = imfs[len(imfs)-1]

    return (imfs, imf_residue )

    
# Do the decomposition on the closing price time series
( imfs, imf_residue ) = emd_analysis( days,ftseinfo['close'])
print('第一次分解')
# plot the residue to see if a clear trend in there
fig = plt.figure(figsize=(12,6))
sp1 = fig.add_subplot(111)
plt.xlabel('date')
plt.ylabel('residue')
sp1.plot_date( x=date_axis, y=imf_residue, linewidth=1, linestyle= 'dotted', color='red' )
plt.legend(loc='lower right')
plt.show()
# Out:
# No handles with labels found to put in legend.
# 第一次分解

# %%
ftseinfo['trend_adjusted_1'] = ftseinfo['close'] - imf_residue

print('第一次去除趋势')
adf_test( ftseinfo['trend_adjusted_1'] )

# Let's look at adjusted prices
fig = plt.figure(figsize=(12,6))
sp1 = fig.add_subplot(111)
plt.xlabel('date')
plt.ylabel('trend adjusted price')

sp1.plot_date( x=date_axis, y=ftseinfo['trend_adjusted_1'],linewidth=1, linestyle= 'dotted', color='green' )
plt.axhline(0, color='black')

plt.legend(loc='lower right')
plt.show()
# Out:
# No handles with labels found to put in legend.
# 第一次去除趋势
# ADF Statistic: -2.892114
# p-value: 0.046273
# p-value阀值:0.05，p-value大于0.05，认为这组时间序列是非平稳的，需要改进。
# Critical Values:
# 	1%: -3.478
# 	5%: -2.883
# 	10%: -2.578

# %%
# Do the decomposition on the price movement series
( imfs, imf_residue ) = emd_analysis( days, ftseinfo['trend_adjusted_1'])
print('第二次分解')
# Check residue to ensure no significant trend information remains
fig = plt.figure(figsize=(12,6))
sp1 = fig.add_subplot(111)
plt.xlabel('date')
plt.ylabel('residue')
sp1.plot_date( x=date_axis, y=imf_residue, color='red' )
plt.axhline(0, color='black')
plt.show()
# Out:
# 第二次分解

# %%
ftseinfo['trend_adjusted_2'] = ftseinfo['trend_adjusted_1'] - imf_residue

print('第二次去除趋势')
adf_test( ftseinfo['trend_adjusted_2'] )

# Dickey-Fuller test for stationary or not
fig = plt.figure(figsize=(12,6))
sp1 = fig.add_subplot(111)
plt.xlabel('date')
plt.ylabel('trend adjusted price')

sp1.plot_date( x=date_axis, y=ftseinfo['trend_adjusted_2'],linewidth=1, linestyle= 'dotted', color='green' )
plt.axhline(0, color='black')

plt.legend(loc='lower right')
plt.show()
# Out:
# No handles with labels found to put in legend.
# 第二次去除趋势
# ADF Statistic: -4.206113
# p-value: 0.000643
# p-value阀值:0.05，p-value大于0.05，认为这组时间序列是非平稳的，需要改进。
# Critical Values:
# 	1%: -3.481
# 	5%: -2.884
# 	10%: -2.578

# %%
( imfs, imf_residue ) = emd_analysis( days, ftseinfo['trend_adjusted_2'])
print('第三次分解')
# Check residue to ensure no significant trend information remains
fig = plt.figure(figsize=(12,6))
sp1 = fig.add_subplot(111)
plt.xlabel('date')
plt.ylabel('residue')
sp1.plot_date( x=date_axis, y=imf_residue, color='red' )
plt.axhline(0, color='black')
plt.show()
# Out:
# 第三次分解

# %%
# Plot each IMF in turn; the highest frequency IMFS are first and lowest are last
for i in range(0,len(imfs)-1):
    fig = plt.figure(figsize=(12,6))
    sp1 = fig.add_subplot(111)
    plt.xlabel('date')
    plt.ylabel('imf %d'%i)
    sp1.plot_date( x=date_axis, y=imfs[i], color='green' )
    plt.axhline(0, color='black')
    plt.show()

# %%
ftseinfo['trend_adjusted_3'] = ftseinfo['trend_adjusted_2'] - imf_residue

print('第三次去除趋势')
adf_test( ftseinfo['trend_adjusted_3'] )

# Dickey-Fuller test for stationary or not
fig = plt.figure(figsize=(12,6))
sp1 = fig.add_subplot(111)
plt.xlabel('date')
plt.ylabel('trend adjusted price')

sp1.plot_date( x=date_axis, y=ftseinfo['trend_adjusted_3'],linewidth=1, linestyle= 'dotted', color='green' )
plt.axhline(0, color='black')

plt.legend(loc='lower right')
plt.show()
# Out:
# No handles with labels found to put in legend.
# 第三次去除趋势
# ADF Statistic: -4.187567
# p-value: 0.000692
# p-value阀值:0.05，p-value大于0.05，认为这组时间序列是非平稳的，需要改进。
# Critical Values:
# 	1%: -3.481
# 	5%: -2.884
# 	10%: -2.578

# %%
( imfs, imf_residue ) = emd_analysis( days, ftseinfo['trend_adjusted_3'])
print('第四次分解')
ftseinfo['trend_adjusted_4'] = ftseinfo['trend_adjusted_3'] - imf_residue

print('第四次去除趋势')
adf_test( ftseinfo['trend_adjusted_4'] )

# Dickey-Fuller test for stationary or not
fig = plt.figure(figsize=(12,6))
sp1 = fig.add_subplot(111)
plt.xlabel('date')
plt.ylabel('trend adjusted price')

sp1.plot_date( x=date_axis, y=ftseinfo['trend_adjusted_4'],linewidth=1, linestyle= 'dotted', color='green' )
plt.axhline(0, color='black')

plt.legend(loc='lower right')
plt.show()
# Out:
# No handles with labels found to put in legend.
# 第四次分解
# 第四次去除趋势
# ADF Statistic: -6.059709
# p-value: 0.000000
# p-value阀值:0.05，p-value大于0.05，认为这组时间序列是非平稳的，需要改进。
# Critical Values:
# 	1%: -3.481
# 	5%: -2.884
# 	10%: -2.578

# %%
 #------------------------------EMA多头判断------------------------------------------------------------------
dhf = ftseinfo
#dhf['close'] = ftseinfo['trend_adjusted_5']
dhf['close'] = imfs[2]
dhf['w_close']=dhf['close'].rolling(5).mean()

dhf['ema5']  = dhf['close'].ewm(span=3).mean()
dhf['ema10']  = dhf['close'].ewm(span=10).mean()
dhf['ema20']  = dhf['close'].ewm(span=30).mean()
dhf['ema60']  = dhf['close'].ewm(span=60).mean()

#---------------------------------------------------------------------------------------
plt.figure(figsize=(15, 5))
plt.title(str(tc))

plt.plot(df['close'], color="green", linewidth=0.3, linestyle="-")
plt.plot(df['ema5'], color="red", linewidth=0.3, linestyle="-")
plt.plot(df['ema20'], color = "blue",  linewidth=0.3, linestyle="-")

# %%
#--------------------------------------------------------------------------------------------------------  
pcn = 1
fwl = 2
swl = 5
dwl = 3
#---------------------------------三SSA-------------------------------------------------
dhf['f_ssa'] = dhf['close'].rolling(2*fwl).apply(ssa,args = (fwl,pcn),raw = True) 
dhf['s_ssa'] = dhf['close'].rolling(2*swl).apply(ssa,args = (swl,pcn),raw = True) 
dhf['w_ssa'] = dhf['w_close'].rolling(2*dwl).apply(ssa,args = (dwl,pcn),raw = True) 
#---------------------------------------------------------------------------------------
plt.figure(figsize=(15, 5))
plt.title(str(tc))

plt.plot(dhf['close'], color="black", linewidth=0.3, linestyle="-")
plt.plot(dhf['f_ssa'], color="green", linewidth=0.3, linestyle="-")
plt.plot(dhf['s_ssa'], color="red", linewidth=0.3, linestyle="-")
plt.plot(dhf['w_ssa'], color = "blue",  linewidth=0.3, linestyle="-")

# %%
#---------------------------------买卖点策略-------------------------------------------------
#DataFrame.diff(periods=1, axis=0) ; periods：移动的幅度，int类型，默认值为1;
# axis：移动的方向，{0 or ‘index’, 1 or ‘columns’}，
# 如果为0或者’index’，则上下移动，如果为1或者’columns’，则左右移动。
dhf['dfe'] = dhf['f_ssa']-dhf['ema5']
dhf['dtf'] = dhf['f_ssa']-dhf['f_ssa'].shift(1) 
dhf['dts'] = dhf['s_ssa']-dhf['s_ssa'].shift(1) 
dhf['dtw'] = dhf['w_ssa']-dhf['w_ssa'].shift(1) 

#df['ddx'] =  (df['dtf']>0.0000)  & (df['dts']>0) & (df['dtw']>0.0000)  
dhf['ddx'] =  (dhf['dtf']>0.0000)  & (dhf['dtw']>0) & (dhf['dfe']>0.0000) 
#print(df['ddx'])

#---------------------------------回测收益-------------------------------------------------
dhf['res'] = np.select([dhf['ddx'] > 0],[df['close']],default = np.nan)  #获取快慢SSA >0的时序
dhf['attack'] = np.select([dhf['ddx'] > 0],[1],default = 0)#获取“双SSA斜率差 >0策略”的时序的触发信号

bs = np.array(dhf['attack'])

#print("买卖信号A:"+str(bs[-1]))

dhf['buy'] = dhf['attack'].shift(1) #下移一行买入信号
bs2 = np.array(dhf['buy'])
#print("买卖信号B:"+str(bs2[-1]))
#print(np.array(df['buy']))

dhf['base_profit'] = 1+0.01*df['pct_chg'].fillna(0) #计算基准每日收益
dhf['prod_base_profit'] = df['base_profit'].cumprod()-1 #计算基准每日收益累乘
dhf['profit'] = np.select([dhf['buy'] == 1],[df['base_profit']],default = 1) #计算策略每日收益
dhf['profit'] = dhf['profit'].fillna(0)
#print(np.array(data['profit']))

dhf['prod_profit'] = dhf['profit'].cumprod()-1#计算策略每日收益累乘
dhf['max_profit'] = dhf['prod_profit'].max()

plt.figure(figsize=(15, 5))
plt.title(str(tc))

plt.plot(dhf['prod_profit'], color="red", linewidth=0.3, linestyle="-")
plt.plot(dhf['prod_base_profit'], color = "blue",  linewidth=0.3, linestyle="-")

print("策略收益率："+str(np.array(dhf['prod_profit'])[-1])) 
print("基准收益率："+str(np.array(dhf['prod_base_profit'])[-1]))
# Out:
# 策略收益率：1.2212306792902794
# 基准收益率：0.22445162101391714
